# %%
import pandas as pd

# %%
pd.read_csv('full_per_2006.csv')
# Out:
#         RK                PLAYER  GP   MPG    TS%   AST    TO   USG  ORR  \
# 0      1.0    Dirk Nowitzki, DAL  81  38.1  0.589  10.2   7.1  27.5  5.0
# 1      2.0     LeBron James, CLE  79  42.5  0.568  17.6   8.8  31.4  3.0
# 2      3.0      Kobe Bryant, LAL  80  41.0  0.559  11.5   8.0  35.3  3.0
# 3      4.0      Dwyane Wade, MIA  75  38.6  0.577  19.8  10.6  30.1  5.0
# 4      5.0    Kevin Garnett, MIN  76  38.9  0.589  16.3   9.5  23.3  9.0
# ..     ...                   ...  ..   ...    ...   ...   ...   ...  ...
# 317  318.0      Mark Madsen, MIN  62  10.9  0.427   8.9  21.0   7.0  9.0
# 318  319.0    Antonio Burks, MEM  57  10.0  0.367  28.6  13.5  15.8  1.0
# 319  320.0    Rafael Araujo, TOR  52  11.6  0.385   7.0  19.6  13.4  8.0
# 320  321.0       Ryan Bowen, HOU  68   9.6  0.338  14.4   7.8   9.4  6.0
# 321  322.0  Jim Jackson, LAL/PHX  40  12.8  0.365  14.8  14.8  16.3  0.0
#
#       DRR  REBR    PER     VA   EWA
# 0    23.5  14.2  28.20  769.9  25.7
# ...
