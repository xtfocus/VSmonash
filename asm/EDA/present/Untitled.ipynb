# %%
import pandas as pd
dat = pd.read_csv("data/phythro_nba.csv", index_col=0)

# %%
dat.head()
# Out:
#    Unnamed: 0.1           Player Height  Weight             College  Country  \
# 0             0      Jerry Smith    6-2   190.0          Louisville      USA
# 1             1   Walker Russell    6-0   170.0  Jacksonville State      NaN
# 2             2       Mark Jones    6-6   215.0     St. Bonaventure      USA
# 3             3  Hakeem Olajuwon    7-0   255.0             Houston  Nigeria
# 4             4     Kevin Willis    7-0   245.0      Michigan State      USA
#
#    Draft_Year Draft_Round Draft_Number  Height_cm Body_fat Hand_length  \
# 0        1963           2           12     187.96      NaN         NaN
# 1        1982           4           78     182.88      NaN         NaN
# 2        1983           4           82     198.12      NaN         NaN
# 3        1984           1            1     213.36      NaN         NaN
# 4        1984           1           11     213.36      NaN         NaN
#
#   Hand_width Standing_reach Wingspan  Wingspan_cm  Standing_reach_cm
# ...

# %%
dat = dat.drop("Unnamed: 0.1", axis=1)

# %%
height_dat = dat[[
    "Player", "Height_cm"]
]

# %%
height_dat.to_csv("height_demo.csv", index=False)
